# %% [markdown]
# # Getting Started
#
# Welcome to the Threat Hunting Lab.
#
# This notebook verifies that:
#
# * Your environment is working correctly
# * The dataset is accessible
# * Python and pandas are properly configured
#
# Before we begin hunting, we need to confirm:
#
# 1. You are in the correct working directory
# 2. The `/data/` folder is accessible
# 3. The lab dataset can be successfully loaded
#
# To run the code in a Jupyter cell, press `CTRL+ENTER`. Let's practice.
#
# Click into the cell below this text, then ress `CTRL+ENTER` on your keyboard to execute the cell below this text.
#
# ---

# %%
print("""
🎉 YOU DID IT! 🎉 
""")

# %% [markdown]
# ## What This Notebook Does
#
# The code below will:
#
# * Print your current working directory
# * Show the files available in your current folder
# * Show the files inside the `/data/` directory
# * Load the lab dataset into a pandas DataFrame
# * Display the first few rows of the dataset
#
# If everything runs without errors, your lab environment is ready.
#
# ---
#
# ## Why This Matters
#
# Threat hunting requires:
#
# * Reliable data access
# * Clean parsing of structured logs
# * Confidence in your analysis environment
#
# Before forming hypotheses or stacking events, we validate the basics.
#
# If the dataset loads successfully, proceed to the next lab.
#
# If you encounter errors:
#
# * Verify the `/data/` directory exists
# * Confirm the filename is correct
# * Re-run the cell
#
# Let’s confirm your environment is operational.
#
# Happy hunting!

# %% [markdown]
# ### Install pandas in GitHub Codespace

# %%
pip install pandas # install pandas for GitHub Codespace

# %% [markdown]
# ### Check Environment & Lab Setup

# %%
import os
import pandas as pd


current_directory = os.getcwd()
print("Current directory:", current_directory)
print("====================================================================================================")
print("Current directory listing:", os.listdir('.'))           # list the contents of the current folder
print("====================================================================================================")
print("Listing of the /data/ folder:", os.listdir('../data/'))        # list the content sof the "data" folder


df1 = pd.read_csv('../data/lab_github.csv',  dtype=str, low_memory=False)
df2 = pd.read_csv('../data/lab_phishing.csv', dtype=str, low_memory=False)
df3 = pd.read_csv('../data/lab_dprk.csv',     dtype=str, low_memory=False)

# ────────────────────────────────────────────────
# Now show all three nicely
# ────────────────────────────────────────────────

print("=== lab_github.csv ===")
display(df1.head())

print("\n=== lab_phishing.csv ===")
display(df2.head())

print("\n=== lab_dprk.csv ===")
display(df3.head())
# Out:
# Current directory: /Users/user/Documents/GitHub/threat-hunting-lab-zia/notebooks
# ====================================================================================================
# Current directory listing: ['getting_started.ipynb', '.ipynb_checkpoints']
# ====================================================================================================
# Listing of the /data/ folder: ['lab_phishing.csv', 'README.md', 'lab_github.csv', 'lab_dprk.csv']
# === lab_github.csv ===
#   No.                      Logged Time                       Event Time  \
# 0   1  January 29, 2026 3:59:05 PM PST  January 29, 2026 3:59:05 PM PST
# 1   2  January 29, 2026 3:59:05 PM PST  January 29, 2026 3:59:05 PM PST
# 2   3  January 29, 2026 3:59:06 PM PST  January 29, 2026 3:59:06 PM PST
# 3   4  January 29, 2026 3:59:06 PM PST  January 29, 2026 3:59:06 PM PST
# 4   5  January 29, 2026 3:59:06 PM PST  January 29, 2026 3:59:06 PM PST
#
#                         User SSL Inspected  \
# 0  mwylie@deepen.zscaler.net            No
# 1  mwylie@deepen.zscaler.net           Yes
# 2  mwylie@deepen.zscaler.net            No
# 3  mwylie@deepen.zscaler.net           Yes
# 4  mwylie@deepen.zscaler.net           Yes
#
#                                                  URL Policy Action  \
# 0            www.msftconnecttest.com/connecttest.txt       Allowed
# 1  array810.prod.do.dsp.mp.microsoft.com/join/?eid=8       Allowed
# 2            www.msftconnecttest.com/connecttest.txt       Allowed
# 3                            login.live.com/rst2.srf       Allowed
# 4                            login.live.com/rst2.srf       Allowed
#
#   Cloud Application Class         Cloud Application Application Status  ...  \
# 0        General Browsing                       NaN                NaN  ...
# 1        General Browsing                       NaN                NaN  ...
# 2        General Browsing                       NaN                NaN  ...
# 3             IT Services  Microsoft Login Services       Unsanctioned  ...
# 4             IT Services  Microsoft Login Services       Unsanctioned  ...
#
#   JA4 Fingerprint C Client-Side Key Exchange Algorithm  \
# 0               NaN                                NaN
# 1               NaN                          secp256r1
# 2               NaN                                NaN
# 3               NaN                          secp256r1
# 4               NaN                          secp256r1
#
#   Server-Side Key Exchange Algorithm Client-Side Digital Signature Algorithm  \
# 0                                NaN                                     NaN
# 1                          secp256r1                     rsa_pss_rsae_sha256
# 2                                NaN                                     NaN
# 3                          secp384r1                     rsa_pss_rsae_sha256
# 4                          secp384r1                     rsa_pss_rsae_sha256
#
#   Server-Side Digital Signature Algorithm Client Key Exchange Proposal  \
# 0                                     NaN                          NaN
# 1                  ecdsa_secp256r1_sha256                ["Classical"]
# 2                                     NaN                          NaN
# 3                     rsa_pss_rsae_sha256                ["Classical"]
# 4                     rsa_pss_rsae_sha256                ["Classical"]
#
#   Client Digital Signature Proposal Download User-Defined File Type  \
# 0                               NaN                             NaN
# 1                     ["Classical"]                             NaN
# 2                               NaN                             NaN
# 3                     ["Classical"]                             NaN
# 4                     ["Classical"]                             NaN
#
#   Upload User-Defined File Type Extranet Resource
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
#
# [5 rows x 132 columns]
# === lab_phishing.csv ===
#   No.                       Logged Time                        Event Time  \
# 0   1  January 30, 2026 12:30:00 PM PST  January 30, 2026 12:30:00 PM PST
# 1   2  January 30, 2026 12:30:30 PM PST  January 30, 2026 12:30:30 PM PST
# 2   3  January 30, 2026 12:30:30 PM PST  January 30, 2026 12:30:30 PM PST
# 3   4  January 30, 2026 12:30:30 PM PST  January 30, 2026 12:30:30 PM PST
# 4   5  January 30, 2026 12:31:01 PM PST  January 30, 2026 12:31:01 PM PST
#
#                      User SSL Inspected  \
# 0  karen@acme.zscaler.net           Yes
# 1  karen@acme.zscaler.net           Yes
# 2  karen@acme.zscaler.net           Yes
# 3  karen@acme.zscaler.net           Yes
# 4  karen@acme.zscaler.net           Yes
#
#                                                  URL Policy Action  \
# 0  www.youtube.com/api/stats/qoe?fmt=398&afmt=251...       Allowed
# 1  www.youtube.com/api/stats/qoe?fmt=398&afmt=251...       Allowed
# 2               mozilla.cloudflare-dns.com/dns-query       Allowed
# 3               mozilla.cloudflare-dns.com/dns-query       Allowed
# 4               mozilla.cloudflare-dns.com/dns-query       Allowed
#
#    Cloud Application Class Cloud Application Application Status  ...  \
# 0          Streaming Media           YouTube       Unsanctioned  ...
# 1          Streaming Media           YouTube       Unsanctioned  ...
# 2  DNS Over HTTPS Services    Cloudflare DNS       Unsanctioned  ...
# 3  DNS Over HTTPS Services    Cloudflare DNS       Unsanctioned  ...
# 4  DNS Over HTTPS Services    Cloudflare DNS       Unsanctioned  ...
#
#   JA4 Fingerprint C Client-Side Key Exchange Algorithm  \
# 0               NaN                          secp256r1
# 1               NaN                          secp256r1
# 2               NaN                          secp256r1
# 3               NaN                          secp256r1
# 4               NaN                          secp256r1
#
#   Server-Side Key Exchange Algorithm Client-Side Digital Signature Algorithm  \
# 0                          secp256r1                     rsa_pss_rsae_sha256
# 1                          secp256r1                     rsa_pss_rsae_sha256
# 2                          secp256r1                     rsa_pss_rsae_sha256
# 3                          secp256r1                     rsa_pss_rsae_sha256
# 4                          secp256r1                     rsa_pss_rsae_sha256
#
#   Server-Side Digital Signature Algorithm Client Key Exchange Proposal  \
# 0                  ecdsa_secp256r1_sha256         ["Classical,Hybrid"]
# 1                  ecdsa_secp256r1_sha256         ["Classical,Hybrid"]
# 2                  ecdsa_secp256r1_sha256         ["Classical,Hybrid"]
# 3                  ecdsa_secp256r1_sha256         ["Classical,Hybrid"]
# 4                  ecdsa_secp256r1_sha256         ["Classical,Hybrid"]
#
#   Client Digital Signature Proposal Download User-Defined File Type  \
# 0                     ["Classical"]                             NaN
# 1                     ["Classical"]                             NaN
# 2                     ["Classical"]                             NaN
# 3                     ["Classical"]                             NaN
# 4                     ["Classical"]                             NaN
#
#   Upload User-Defined File Type Extranet Resource
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
#
# [5 rows x 132 columns]
# === lab_dprk.csv ===
#   No.                      Logged Time                       Event Time  \
# 0   1  January 27, 2026 2:30:23 PM PST  January 27, 2026 2:30:23 PM PST
# 1   2  January 27, 2026 2:30:23 PM PST  January 27, 2026 2:30:23 PM PST
# 2   3  January 27, 2026 2:30:23 PM PST  January 27, 2026 2:30:23 PM PST
# 3   4  January 27, 2026 2:30:23 PM PST  January 27, 2026 2:30:23 PM PST
# 4   5  January 27, 2026 2:30:23 PM PST  January 27, 2026 2:30:23 PM PST
#
#                      User SSL Inspected  \
# 0  karen@acme.zscaler.net            No
# 1  karen@acme.zscaler.net           Yes
# 2  karen@acme.zscaler.net            No
# 3  karen@acme.zscaler.net            No
# 4  karen@acme.zscaler.net            No
#
#                                                 URL  \
# 0                                   ssl.gstatic.com
# 1  self.events.data.microsoft.com/onecollector/1.0/
# 2                                   ssl.gstatic.com
# 3           detectportal.firefox.com/canonical.html
# 4         detectportal.firefox.com/success.txt?ipv4
#
#                                 Policy Action Cloud Application Class  \
# 0  Dropped due to failed client SSL handshake        General Browsing
# 1                                     Allowed        General Browsing
# 2  Dropped due to failed client SSL handshake        General Browsing
# 3                                     Allowed        General Browsing
# 4                                     Allowed        General Browsing
#
#   Cloud Application Application Status  ... JA4 Fingerprint C  \
# 0               NaN                NaN  ...               NaN
# 1               NaN                NaN  ...               NaN
# 2               NaN                NaN  ...               NaN
# 3               NaN                NaN  ...               NaN
# 4               NaN                NaN  ...               NaN
#
#   Client-Side Key Exchange Algorithm Server-Side Key Exchange Algorithm  \
# 0                                NaN                                NaN
# 1                          secp256r1                          secp256r1
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#   Client-Side Digital Signature Algorithm  \
# 0                                     NaN
# 1                     rsa_pss_rsae_sha256
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Server-Side Digital Signature Algorithm Client Key Exchange Proposal  \
# 0                                     NaN                ["Classical"]
# 1                     rsa_pss_rsae_sha256                ["Classical"]
# 2                                     NaN                ["Classical"]
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#   Client Digital Signature Proposal Download User-Defined File Type  \
# 0                     ["Classical"]                             NaN
# 1                     ["Classical"]                             NaN
# 2                     ["Classical"]                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#   Upload User-Defined File Type Extranet Resource
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
#
# [5 rows x 132 columns]
